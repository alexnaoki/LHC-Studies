# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">
#
# *Esse Notebook é um <b>compilado</b> baseado no livro [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) por Jake VanderPlas; o conteúdo está disponível [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*

# %% [markdown]
# > *The Python Data Science Handbook* by Jake VanderPlas (O’Reilly). Copyright 2016 Jake VanderPlas, 978-1-491-91205-8.

# %% [markdown]
# # Manipulação de dados com <b>Pandas</b>

# %% [markdown]
# Pandas é um pacote cujo é construído baseado no NumPy, provendo uma maneira eficiente a implementação de ``Dataframe``. ``Dataframe``s são essenciais em arrays multidimensionais cujo são definidos por linhas e colunas, as vezes, possuindo tipos de dados heterogêneos e até com dados faltosos.

# %% [markdown]
# Começaremos com a importação do NumPy e Pandas:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()

# %%
start = dt.datetime(2011,1,25,13,10,0)

df['Datetime'] = pd.date_range(start=start, periods=400000, freq='10min')

# %%
df
# Out:
#                   Datetime
# 0      2011-01-25 13:10:00
# 1      2011-01-25 13:20:00
# 2      2011-01-25 13:30:00
# 3      2011-01-25 13:40:00
# 4      2011-01-25 13:50:00
# 5      2011-01-25 14:00:00
# 6      2011-01-25 14:10:00
# 7      2011-01-25 14:20:00
# 8      2011-01-25 14:30:00
# 9      2011-01-25 14:40:00
# 10     2011-01-25 14:50:00
# 11     2011-01-25 15:00:00
# 12     2011-01-25 15:10:00
# 13     2011-01-25 15:20:00
# 14     2011-01-25 15:30:00
# 15     2011-01-25 15:40:00
# 16     2011-01-25 15:50:00
# 17     2011-01-25 16:00:00
# 18     2011-01-25 16:10:00
# 19     2011-01-25 16:20:00
# 20     2011-01-25 16:30:00
# 21     2011-01-25 16:40:00
# 22     2011-01-25 16:50:00
# 23     2011-01-25 17:00:00
# 24     2011-01-25 17:10:00
# 25     2011-01-25 17:20:00
# 26     2011-01-25 17:30:00
# 27     2011-01-25 17:40:00
# 28     2011-01-25 17:50:00
# 29     2011-01-25 18:00:00
# ...                    ...
# 399970 2018-09-03 02:50:00
# 399971 2018-09-03 03:00:00
# ...

# %%
df['Variavel_01'] = np.random.uniform(low=-0.1, high=1, size=len(df['Datetime']))

# %%
df['Variavel_01'] += 17

# %%
df.loc[df['Variavel_01'] > 17.4, 'Variavel_01'] += 5

# %%
df.describe()
# Out:
#          Variavel_01
# count  400000.000000
# mean       20.187284
# std         2.767225
# min        16.900006
# 25%        17.176343
# 50%        22.451991
# 75%        22.725778
# max        23.000000

# %%
plt.plot(df['Variavel_01'][0:500])
